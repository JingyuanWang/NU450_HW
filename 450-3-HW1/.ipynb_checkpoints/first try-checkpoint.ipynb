# %%
import numpy as np
import pandas as pd
import os,sys,inspect
import scipy.stats as stats
import scipy.optimize as opt
from scipy.stats import norm
import scipy.integrate as integrate
from scipy.io import loadmat
import econtools 
import econtools.metrics as mt
import statsmodels.discrete.discrete_model as sm
import matplotlib.pyplot as plt
import itertools as it
import copy
import importlib
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# my functions
dirpath = os.getcwd()
i = 0
while(os.path.basename(dirpath) != "NU450_HW") and (i<=10):
    dirpath = os.path.dirname(dirpath)
    i = i + 1
targetdir = dirpath + '/450-3-HW1'
if targetdir not in sys.path:
    sys.path.insert(0,targetdir)

from single_agent_dynamics import est_func_step1_transitions
from single_agent_dynamics import est_func_step2_estimate_EV

from single_agent_dynamics import agent_choices
importlib.reload(est_func_step1_transitions)
importlib.reload(est_func_step2_estimate_EV)
importlib.reload(agent_choices)
# Out:
# <module 'single_agent_dynamics.agent_choices' from '/Users/jingyuanwang/GitHub/NU450_HW/450-3-HW1/single_agent_dynamics/agent_choices.py'>

# %%
# %pdb ON

# %% [markdown]
# # Path

# %%
datapath = '/Users/jingyuanwang/Dropbox/Course/ECON/IO/NU450/NU450_HW/450-3-HW1/data'

# %% [markdown]
# # import data

# %%
df = pd.read_csv(datapath + '/ddc_pset.csv')

# %%
data = agent_choices.observations(df, n_rc_grids = 5, weight= True)
# Out:
# # ---- number of obs in each bin ----------
# (31.469, 37.7]     5000
# (37.7, 43.9]      20000
# (43.9, 50.1]      41000
# (50.1, 56.3]      29000
# (56.3, 62.5]       5000
# Name: rc, dtype: int64
# # ---- average probability in each bin ----------
# # ---- transition matrix for all states ----------

# %% [markdown]
# # estimation

# %%
importlib.reload(agent_choices)

# %%
estimation = agent_choices.estimation(data)

# %%
theta = np.ones(2)

# %%
beta = 0.95

# %%
estimation.df
# Out:
#     state_var_id  x  rc_grid_id         rc_grid         rc         P  \
# 0              0  1           0  (31.469, 37.7]  34.900000  0.021313
# 1              1  1           1    (37.7, 43.9]  40.950000  0.011799
# 2              2  1           2    (43.9, 50.1]  47.158537  0.005011
# 3              3  1           3    (50.1, 56.3]  52.517241  0.001780
# 4              4  1           4    (56.3, 62.5]  59.700000  0.000000
# 5              5  2           0  (31.469, 37.7]  34.900000  0.077103
# 6              6  2           1    (37.7, 43.9]  40.950000  0.034848
# 7              7  2           2    (43.9, 50.1]  47.158537  0.018349
# 8              8  2           3    (50.1, 56.3]  52.517241  0.009176
# 9              9  2           4    (56.3, 62.5]  59.700000  0.004249
# 10            10  3           0  (31.469, 37.7]  34.900000  0.241155
# 11            11  3           1    (37.7, 43.9]  40.950000  0.129932
# 12            12  3           2    (43.9, 50.1]  47.158537  0.063607
# 13            13  3           3    (50.1, 56.3]  52.517241  0.036158
# 14            14  3           4    (56.3, 62.5]  59.700000  0.011947
# 15            15  4           0  (31.469, 37.7]  34.900000  0.398207
# 16            16  4           1    (37.7, 43.9]  40.950000  0.275245
# 17            17  4           2    (43.9, 50.1]  47.158537  0.149294
# 18            18  4           3    (50.1, 56.3]  52.517241  0.095757
# 19            19  4           4    (56.3, 62.5]  59.700000  0.047045
# 20            20  5           0  (31.469, 37.7]  34.900000  0.601869
# 21            21  5           1    (37.7, 43.9]  40.950000  0.435897
# 22            22  5           2    (43.9, 50.1]  47.158537  0.297888
# 23            23  5           3    (50.1, 56.3]  52.517241  0.198689
# 24            24  5           4    (56.3, 62.5]  59.700000  0.091027
# 25            25  6           0  (31.469, 37.7]  34.900000  0.661157
# 26            26  6           1    (37.7, 43.9]  40.950000  0.572903
# 27            27  6           2    (43.9, 50.1]  47.158537  0.420668
# 28            28  6           3    (50.1, 56.3]  52.517241  0.311126
# 29            29  6           4    (56.3, 62.5]  59.700000  0.142857
# 30            30  7           0  (31.469, 37.7]  34.900000  0.805310
# 31            31  7           1    (37.7, 43.9]  40.950000  0.650718
# 32            32  7           2    (43.9, 50.1]  47.158537  0.522050
# 33            33  7           3    (50.1, 56.3]  52.517241  0.397918
# 34            34  7           4    (56.3, 62.5]  59.700000  0.220025
#
#     num_of_obs
# 0         1173
# 1         4068
# 2         6984
# 3         4495
# 4          560
# 5          856
# 6         4247
# 7         6758
# 8         4577
# 9          706
# 10        1074
# 11        3371
# 12        7059
# 13        4425
# 14         837
# 15         781
# 16        2961
# 17        6591
# 18        4313
# 19         829
# 20         535
# 21        2340
# 22        5445
# 23        3815
# 24         769
# 25         242
# 26        1550
# 27        3832
# 28        2957
# 29         490
# 30         339
# 31        1463
# 32        4331
# 33        4418
# 34         809

# %%
np.log(precision)
# Out:
# -690.7755278982137

# %%
u = estimation._get_perperiod_u(theta)
transition = estimation.transition.copy()

# %%
transition['0'].shape
# Out:
# (35, 35)

# %%
df2 = df[['i', 'x']].groupby('i').agg('count')

# %%
df2
# Out:
#         x
# i
# 1     100
# 2     100
# 3     100
# 4     100
# 5     100
# 6     100
# 7     100
# 8     100
# 9     100
# 10    100
# 11    100
# 12    100
# 13    100
# 14    100
# 15    100
# 16    100
# 17    100
# 18    100
# 19    100
# 20    100
# 21    100
# 22    100
# 23    100
# 24    100
# 25    100
# 26    100
# 27    100
# 28    100
# 29    100
# 30    100
# ...   ...
# 971   100
# 972   100
# 973   100
# 974   100
# 975   100
# 976   100
# 977   100
# 978   100
# 979   100
# 980   100
# 981   100
# 982   100
# 983   100
# 984   100
# 985   100
# 986   100
# 987   100
# 988   100
# 989   100
# 990   100
# 991   100
# 992   100
# 993   100
# 994   100
# 995   100
# 996   100
# 997   100
# 998   100
# 999   100
# 1000  100
#
# [1000 rows x 1 columns]

# %%
EV = find_fixed_point(u, transition)
# Out:
# total iter : 519
# final diff : 9.604491424397565e-09

# %%
EV
# Out:
# {'0': array([931.77257159, 939.6952077 , 949.84883816, 962.50540922,
#         969.4726718 , 931.77257159, 939.6952077 , 949.84883816,
#         962.50540922, 969.4726718 , 931.77257159, 939.6952077 ,
#         949.84883816, 962.50540922, 969.4726718 , 931.77257159,
#         939.6952077 , 949.84883816, 962.50540922, 969.4726718 ,
#         931.77257159, 939.6952077 , 949.84883816, 962.50540922,
#         969.4726718 , 931.77257159, 939.6952077 , 949.84883816,
#         962.50540922, 969.4726718 , 931.77257159, 939.6952077 ,
#         949.84883816, 962.50540922, 969.4726718 ]),
#  '1': array([931.77257159, 939.6952077 , 949.84883816, 962.50540922,
#         969.4726718 , 931.77257159, 939.6952077 , 949.84883816,
#         962.50540922, 969.4726718 , 931.77257159, 939.6952077 ,
#         949.84883816, 962.50540922, 969.4726718 , 931.77257159,
#         939.6952077 , 949.84883816, 962.50540922, 969.4726718 ,
#         931.77257159, 939.6952077 , 949.84883816, 962.50540922,
#         969.4726718 , 931.77257159, 939.6952077 , 949.84883816,
#         962.50540922, 969.4726718 , 931.77257159, 939.6952077 ,
#         949.84883816, 962.50540922, 969.4726718 ])}

# %%
EV = EV0.copy()
EV_new = {}

# %%
delta_0 = u['0'] + beta* EV['0']
delta_1 = u['1'] + beta* EV['1']
diff_in_delta = delta_0 - delta_1

# %%
np.exp(delta_0) + np.exp(delta_1)
# Out:
# array([3.71071138e+15, 1.57376105e+18, 7.82117442e+20, 1.66160540e+23,
#        2.18756178e+26, 3.71071138e+15, 1.57376105e+18, 7.82117442e+20,
#        1.66160540e+23, 2.18756178e+26, 3.71071138e+15, 1.57376105e+18,
#        7.82117442e+20, 1.66160540e+23, 2.18756178e+26, 3.71071138e+15,
#        1.57376105e+18, 7.82117442e+20, 1.66160540e+23, 2.18756178e+26,
#        3.71071138e+15, 1.57376105e+18, 7.82117442e+20, 1.66160540e+23,
#        2.18756178e+26, 3.71071138e+15, 1.57376105e+18, 7.82117442e+20,
#        1.66160540e+23, 2.18756178e+26, 3.71071138e+15, 1.57376105e+18,
#        7.82117442e+20, 1.66160540e+23, 2.18756178e+26])

# %%
EV_new['0'] = transition['0'] @ (delta_1 + np.log(1 + diff_in_delta))
EV_new['1'] = transition['1'] @ (delta_1 + np.log(1 + diff_in_delta))

# %%
np.log(diff_in_delta)
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
diff_in_delta
# Out:
# array([-33.9       , -39.95      , -46.15853659, -51.51724138,
#        -58.7       , -32.9       , -38.95      , -45.15853659,
#        -50.51724138, -57.7       , -31.9       , -37.95      ,
#        -44.15853659, -49.51724138, -56.7       , -30.9       ,
#        -36.95      , -43.15853659, -48.51724138, -55.7       ,
#        -29.9       , -35.95      , -42.15853659, -47.51724138,
#        -54.7       , -28.9       , -34.95      , -41.15853659,
#        -46.51724138, -53.7       , -27.9       , -33.95      ,
#        -40.15853659, -45.51724138, -52.7       ])
